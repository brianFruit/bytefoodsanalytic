# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from dateutil.relativedelta import relativedelta
from dateutil.parser import parse
from collections import OrderedDict

plt.rcParams['figure.figsize'] = [15, 20]

# %% [markdown]
# ## Load Sales Data and Import into a Pandas Dataframe

# %%
df = pd.read_csv("./data/items_purchased.csv")
df['naive_date_time'] = pd.to_datetime(df['date_time'].astype(str).str[:-3])
df.iloc[:10]
# Out:
#    kiosk_id  product_id                                          card_hash  \
# 0       108        2457  FEaD8IUmESlpzvPRYyZhMyUv/CRtDNIUyprR5w7e/mPkFz...
# 1       220        2884  N8JjRgpqKnQ8BDp+XtxBkfM0If/9GBL+rsOalHjHLdIM8B...
# 2       182        2937  svL2pR3SC6O+B/Kg+78gJsiKDxvCtSUohDLGjj02tGC0MS...
# 3       339        3814  kzaHILrWFehUeo6gjZV1EwvZHNTXGNqTY/Hzv+mL9Bg+vR...
# 4       230        4149  4ox+j2exAB/xLlyHteKO/cNoSdLFb3T29mkacbTAf7ECiX...
# 5       391        4201  3ExgFAomm7KRC3Ju5zdxHR5sGhaNuvdgXGCis0iD3GbtZG...
# 6       232        4111  hOB3nBlofMM/2khWcX9O2CoUZ4YyCFSXB6vbCowurdMCLl...
# 7       391        4201  3ExgFAomm7KRC3Ju5zdxHR5sGhaNuvdgXGCis0iD3GbtZG...
# 8       391        4201  56e0BQgz6p4MkLYd7Ln7mfigk9t6HxTS0riVabfsuCdL66...
# 9       391        4201  4tqsacWv4yYY9d2ntipXbwzxIqDlkf2c2JPqs+Oitm/rVj...
#
#                 date_time  fc_number     naive_date_time
# 0  2017-12-06 22:06:36-08       20.0 2017-12-06 22:06:36
# 1  2018-08-08 14:18:09-07        NaN 2018-08-08 14:18:09
# 2  2017-10-20 18:22:10-07        NaN 2017-10-20 18:22:10
# 3  2018-06-13 01:30:06-07       48.0 2018-06-13 01:30:06
# 4  2017-10-19 16:27:17-07        NaN 2017-10-19 16:27:17
# 5  2018-08-15 18:22:15-07       48.0 2018-08-15 18:22:15
# 6  2018-05-03 07:24:09-07        NaN 2018-05-03 07:24:09
# 7  2018-08-15 18:22:15-07       48.0 2018-08-15 18:22:15
# 8  2018-07-20 15:50:31-07       48.0 2018-07-20 15:50:31
# 9  2018-02-01 16:13:54-08       48.0 2018-02-01 16:13:54

# %% [markdown]
# ## Extract Basic Information from Data

# %%
start_date = df["naive_date_time"].min()
end_date = df["naive_date_time"].max()

print("Samples from %s to %s" % (start_date, end_date))
print("unique kiosk_id: " + str(df["kiosk_id"].nunique()))
print("unique product_id: " + str(df["product_id"].nunique()))
print("unique card_hash: " + str(df["card_hash"].nunique()))
print("unique fc_number: " + str(df["fc_number"].nunique()))

print("missing card_hash: " + str(len(df[df["card_hash"].isna()])))
print("missing fc_number: " + str(len(df[df["fc_number"].isna()])))
# Out:
# Samples from 2017-09-27 00:07:36 to 2018-09-25 14:34:46
# unique kiosk_id: 546
# unique product_id: 330
# unique card_hash: 119780
# unique fc_number: 46
# missing card_hash: 1106
# missing fc_number: 592

# %% [markdown]
# ## Break Sales Data Down into Months and Plot Montly Transactions on Bar Graph

# %%
current = start_date
monthly_data = OrderedDict()
while current <= end_date + relativedelta(months=+1):
    month = current.month
    year = current.year
    monthly_data[str(year) + '-' + str(month).zfill(2)] = df[(df.naive_date_time.dt.month == current.month) & (df.naive_date_time.dt.year == current.year)]
    current += relativedelta(months=+1)

print (monthly_data.keys())
# Out:
# ['2017-09', '2017-10', '2017-11', '2017-12', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07', '2018-08', '2018-09']

# %%
month_year = []
num_transaction = []
for key in monthly_data:
    month_year.append(key)
    num_transaction.append(len(monthly_data[key]))

plt.bar(month_year, num_transaction)
plt.show()

# %% [markdown]
# ## Check How Day of Week can Affect Sales
# #### As expected, weekend sales are the weakest followed by Fridays. This analysis can be broken down into individual kiosks to see if any kiosk behaves differently.

# %%
sales = []
for weekday in range(7):
    sales.append(len(df[df.naive_date_time.dt.weekday==weekday]))
plt.bar(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], sales)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Aggregating Data
# #### Find the Top 15 Popular Products and Weakest Performing 5 Kiosks over the 12 Months

# %%
bottom5_kiosk = []
top15_product = []

idx = 0
for key in monthly_data:
    ranked_kiosk = monthly_data[key].groupby("kiosk_id")["kiosk_id"].agg(np.size).sort_values(ascending=False)
    ranked_product = monthly_data[key].groupby("product_id")["product_id"].agg(np.size).sort_values(ascending=False)
    bottom5_kiosk.append(ranked_kiosk[-5:]/num_transaction[idx])
    top15_product.append(ranked_product[:15]/num_transaction[idx])
    idx += 1

# %% [markdown]
# #### Analyze the Weakest Performing Kiosks over the 12 Months by Plotting them over Time

# %%
bottom_kiosk_growth = set()
for kiosk in bottom5_kiosk:
    bottom_kiosk_growth = bottom_kiosk_growth.union(set(kiosk.index))
print("number of bottom kiosks:", len(bottom_kiosk_growth))

i = j = 0
for kiosk in bottom_kiosk_growth:
    kiosk_transaction = []
    for t in month_year:
        kiosk_transaction.append(len(monthly_data[t][monthly_data[t].kiosk_id == kiosk]))
    if i%10 == 0:
        lines = []
        plt.subplot(int("22" + str(j+1)))
        j += 1
    lines.append(plt.plot(month_year, kiosk_transaction, label=kiosk)[0])
    plt.legend(handles=lines)
    plt.xticks(rotation=90)
    i += 1

plt.show()
# Out:
# ('number of bottom kiosks:', 40)

# %% [markdown]
# #### Analyze the Popular Products over the 12 Months by Plotting them over Time

# %%
top_product_growth = set()
for product in top15_product:
    top_product_growth = top_product_growth.union(set(product.index))
print("number of top products:", len(top_product_growth))

i = j = 0
for product in top_product_growth:
    product_transaction = []
    for t in month_year:
        product_transaction.append(len(monthly_data[t][monthly_data[t].product_id == product]))
    if i%10 == 0:
        lines = []
        plt.subplot(int("22" + str(j+1)))
        j += 1
    lines.append(plt.plot(month_year, product_transaction, label=product)[0])
    plt.legend(handles=lines)
    plt.xticks(rotation=90)
    i += 1

plt.show()
# Out:
# ('number of top products:', 34)

# %% [markdown]
# #### Further Break the Data Down to Weekly and Zoom in to See Several Hand-picked Weak Kiosks for their Decreasing Sales

# %%
unique_kiosk_id = df.kiosk_id.unique()
kiosk_weekly_df = pd.DataFrame(index=unique_kiosk_id)

current = start_date
i = 0
while current <= end_date + relativedelta(weeks=+1):
    current_df = df[(df.naive_date_time >= current) & (df.naive_date_time < current + relativedelta(weeks=+1))].groupby("kiosk_id")["kiosk_id"].agg(np.size)
    current_df.name = i
    kiosk_weekly_df = kiosk_weekly_df.join(current_df)
    i += 1
    current += relativedelta(weeks=+1)

# %%
weak_kiosks = [747, 877, 254]
lines = plt.plot(kiosk_weekly_df.loc[weak_kiosks].T.fillna(0))
for i in range(len(weak_kiosks)):
    lines[i].set_label(weak_kiosks[i])
plt.xticks(rotation=90)
plt.legend(handles=lines)
plt.show()

# %%
id = 303
kiosk_df = kiosk_weekly_df.T.fillna(0)
kiosk_lower_band = kiosk_df.rolling(4, center=True).mean() - 1.25* kiosk_df.rolling(4, center=True).std()
plt.plot(kiosk_lower_band[id])
plt.plot(kiosk_df.rolling(4, center=True).mean()[id])
plt.plot(kiosk_df[id])
plt.show()

# %%
ranked_kiosk.iloc[0:10]
# Out:
# (kiosk_id
#  680     1019
#  303      789
#  1166     787
#  956      723
#  1110     699
#  955      692
#  636      686
#  423      669
#  589      669
#  58       650
#  Name: kiosk_id, dtype: int64,
#  ['2017-09',
#   '2017-10',
#   '2017-11',
#   '2017-12',
#   '2018-01',
#   '2018-02',
#   '2018-03',
#   '2018-04',
#   '2018-05',
#   '2018-06',
#   '2018-07',
#   '2018-08',
#   '2018-09'])
