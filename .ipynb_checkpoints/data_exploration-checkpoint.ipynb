# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from dateutil.relativedelta import relativedelta
from dateutil.parser import parse
from collections import OrderedDict

plt.rcParams['figure.figsize'] = [15, 20]

# %%
df = pd.read_csv("./data/items_purchased.csv")
df['naive_date_time'] = pd.to_datetime(df['date_time'].astype(str).str[:-3])
df
# Out:
#          kiosk_id  product_id  \
# 0             108        2457
# 1             220        2884
# 2             182        2937
# 3             339        3814
# 4             230        4149
# 5             391        4201
# 6             232        4111
# 7             391        4201
# 8             391        4201
# 9             391        4201
# 10            467        2603
# 11            467        2603
# 12             92        4148
# 13            467        2603
# 14           1110        6123
# 15            485        4200
# 16            400        4454
# 17            196        4430
# 18            355        4430
# 19            473        4454
# 20            355        4430
# 21            549        4167
# 22            549        4167
# 23            549        4167
# 24            548        3818
# 25            548        4167
# 26            548        4167
# 27            547        3818
# 28            401        2864
# 29            219        4199
# ...           ...         ...
# 1115542      1043        4714
# 1115543       745        2784
# 1115544      1118        4630
# 1115545       745        4210
# 1115546       745        4793
# 1115547       745        4061
# 1115548       989        5111
# 1115549       989        4101
# 1115550       989        4101
# 1115551       989        4061
# 1115552       831        2350
# 1115553       831        5779
# 1115554       831        4532
# 1115555       800        4403
# 1115556       566        2784
# 1115557       680        5779
# 1115558      1187        3422
# 1115559      1187        5115
# 1115560      1187        4440
# 1115561      1187        4793
# 1115562       805        4101
# 1115563       182        5695
# 1115564       340        5695
# 1115565       340        4859
# 1115566       340        2350
# 1115567       340        3445
# 1115568       340        2350
# 1115569       340        2360
# 1115570       340        2360
# 1115571       340        3445
#
#                                                  card_hash  \
# 0        FEaD8IUmESlpzvPRYyZhMyUv/CRtDNIUyprR5w7e/mPkFz...
# 1        N8JjRgpqKnQ8BDp+XtxBkfM0If/9GBL+rsOalHjHLdIM8B...
# 2        svL2pR3SC6O+B/Kg+78gJsiKDxvCtSUohDLGjj02tGC0MS...
# 3        kzaHILrWFehUeo6gjZV1EwvZHNTXGNqTY/Hzv+mL9Bg+vR...
# 4        4ox+j2exAB/xLlyHteKO/cNoSdLFb3T29mkacbTAf7ECiX...
# 5        3ExgFAomm7KRC3Ju5zdxHR5sGhaNuvdgXGCis0iD3GbtZG...
# 6        hOB3nBlofMM/2khWcX9O2CoUZ4YyCFSXB6vbCowurdMCLl...
# 7        3ExgFAomm7KRC3Ju5zdxHR5sGhaNuvdgXGCis0iD3GbtZG...
# 8        56e0BQgz6p4MkLYd7Ln7mfigk9t6HxTS0riVabfsuCdL66...
# 9        4tqsacWv4yYY9d2ntipXbwzxIqDlkf2c2JPqs+Oitm/rVj...
# 10       EnrjyyIcDB3X9ug6/M8Kiv3K+H8ea/a40z6xlR5JlYNrtq...
# 11       EnrjyyIcDB3X9ug6/M8Kiv3K+H8ea/a40z6xlR5JlYNrtq...
# 12       Uj7rq3jVSggjafc/6QqzNqtxRRjbHEFU2UnN1FhfJRKZqs...
# 13       58WNwMiF5u0wD0t4VXYoOR74j0x/0LSzGX07/paNr5qw9Y...
# 14       aXKwvh3FKPQnAmhr/Xr7morkvOHFlNlNsWhodV07ih/3dn...
print("unique fc_number: " + str(df["fc_number"].nunique()))

print("missing card_hash: " + str(len(df[df["card_hash"].isna()])))
print("missing fc_number: " + str(len(df[df["fc_number"].isna()])))
# Out:
# Samples from 2017-09-27 00:07:36 to 2018-09-25 14:34:46
# unique kiosk_id: 546
# unique product_id: 330
# unique card_hash: 119780
# unique fc_number: 46
# missing card_hash: 1106
# missing fc_number: 592

# %%
current = start_date
monthly_data = OrderedDict()
while current <= end_date + relativedelta(months=+1):
    month = current.month
    year = current.year
    monthly_data[str(year) + '-' + str(month)] = df[(df.naive_date_time.dt.month == current.month) & (df.naive_date_time.dt.year == current.year)]
    current += relativedelta(months=+1)

print (monthly_data.keys())
# Out:
# odict_keys(['2017-9', '2017-10', '2017-11', '2017-12', '2018-1', '2018-2', '2018-3', '2018-4', '2018-5', '2018-6', '2018-7', '2018-8', '2018-9'])

# %%
month_year = []
num_transaction = []
for key in monthly_data:
    month_year.append(key)
    num_transaction.append(len(monthly_data[key]))

plt.bar(month_year, num_transaction)
plt.show()

# %%
bottom5_kiosk = []
top15_product = []

idx = 0
for key in monthly_data:
    ranked_kiosk = monthly_data[key].groupby("kiosk_id")["kiosk_id"].agg(np.size).sort_values(ascending=False)
    ranked_product = monthly_data[key].groupby("product_id")["product_id"].agg(np.size).sort_values(ascending=False)
    bottom5_kiosk.append(ranked_kiosk[-5:]/num_transaction[idx])
    top15_product.append(ranked_product[:15]/num_transaction[idx])
    idx += 1

# %%
bottom_kiosk_growth = set()
for kiosk in bottom5_kiosk:
    bottom_kiosk_growth = bottom_kiosk_growth.union(set(kiosk.index))
print("number of top products:", len(bottom_kiosk_growth))

i = j = 0
for kiosk in bottom_kiosk_growth:
    kiosk_transaction = []
    for t in month_year:
        kiosk_transaction.append(len(monthly_data[t][monthly_data[t].kiosk_id == kiosk]))
    if i%10 == 0:
        lines = []
        plt.subplot(int("22" + str(j+1)))
        j += 1
    lines.append(plt.plot(month_year, kiosk_transaction, label=kiosk)[0])
    plt.legend(handles=lines)
    i += 1

plt.show()
# Out:
# number of top products: 40

# %%
top_product_growth = set()
for product in top15_product:
    top_product_growth = top_product_growth.union(set(product.index))
print("number of top products:", len(top_product_growth))

i = j = 0
for product in top_product_growth:
    product_transaction = []
    for t in month_year:
        product_transaction.append(len(monthly_data[t][monthly_data[t].product_id == product]))
    if i%10 == 0:
        lines = []
        plt.subplot(int("22" + str(j+1)))
        j += 1
    lines.append(plt.plot(month_year, product_transaction, label=product)[0])
    plt.legend(handles=lines)
    i += 1

plt.show()
# Out:
# number of top products: 34

# %%
unique_kiosk_id = df.kiosk_id.unique()
kiosk_weekly_df = pd.DataFrame(index=unique_kiosk_id)

current = start_date
i = 0
while current <= end_date + relativedelta(months=+1):
    week = "week" + str(i)
    current = start_date + relativedelta(months=+1)
    current_df = df[(df.naive_date_time >= current) & (df.naive_date_time < current + relativedelta(weeks=+1))].groupby("kiosk_id")["kiosk_id"].agg(np.size)
    current_df.name = week
    kiosk_weekly_df = kiosk_weekly_df.join(current_df)
    i += 1
    current += relativedelta(weeks=+1)

# %%
# Out:
# 3711
